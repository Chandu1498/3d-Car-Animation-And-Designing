# %% [markdown]
# # Lab Assignment 3

# %% [markdown]
# # motivational quotes

# %%
# load text
filename = 'motivation quotes.txt'
file = open(filename, 'rt')
mot = file.read()
file.close()
mot
# Out:
# '1.If you want to achieve greatness stop asking for permission.\n2.Things work out best for those who make the best of how things work out\n3.To live a creative life, we must lose our fear of being wrong.\n4.If you are not willing to risk the usual you will have to settle for the ordinary.\n5.Trust because you are willing to accept the risk, not because it’s safe or certain.\n6.Take up one idea. Make that one idea your life - think of it, dream of it, live on that idea. Let the brain, muscles, nerves, every part of your body, be full of that idea, and just leave every other idea alone. This is the way to success.\n7.All our dreams can come true if we have the courage to pursue them. \n8.Good things come to people who wait, but better things come to those who go out and get them.\n9.If you do what you always did, you will get what you always got\n10.Success is walking from failure to failure with no loss of enthusiasm.\n11.Just when the caterpillar thought the world was ending, he tur
# ...

# %%
from nltk.tokenize import sent_tokenize
mot_sent=sent_tokenize(mot)
mot_sent
# Out:
# ['1.If you want to achieve greatness stop asking for permission.',
#  '2.Things work out best for those who make the best of how things work out\n3.To live a creative life, we must lose our fear of being wrong.',
#  '4.If you are not willing to risk the usual you will have to settle for the ordinary.',
#  '5.Trust because you are willing to accept the risk, not because it’s safe or certain.',
#  '6.Take up one idea.',
#  'Make that one idea your life - think of it, dream of it, live on that idea.',
#  'Let the brain, muscles, nerves, every part of your body, be full of that idea, and just leave every other idea alone.',
#  'This is the way to success.',
#  '7.All our dreams can come true if we have the courage to pursue them.',
#  '8.Good things come to people who wait, but better things come to those who go out and get them.',
#  '9.If you do what you always did, you will get what you always got\n10.Success is walking from failure to failure with no loss of enthusiasm.',
# ...

# %%
import nltk
import nltk.tokenize as nt
import re


# Removing Square Brackets and Extra Spaces
mot_text = re.sub(r'\[[0-9]*\]', ' ', mot)  
mot_text = re.sub(r'\s+', ' ', mot_text) 

# Removing special characters and digits
mot_text = re.sub('[^a-zA-Z]', ' ', mot_text )  
mot_text = re.sub(r'\s+', ' ', mot_text)



mot_text
# Out:
# ' If you want to achieve greatness stop asking for permission Things work out best for those who make the best of how things work out To live a creative life we must lose our fear of being wrong If you are not willing to risk the usual you will have to settle for the ordinary Trust because you are willing to accept the risk not because it s safe or certain Take up one idea Make that one idea your life think of it dream of it live on that idea Let the brain muscles nerves every part of your body be full of that idea and just leave every other idea alone This is the way to success All our dreams can come true if we have the courage to pursue them Good things come to people who wait but better things come to those who go out and get them If you do what you always did you will get what you always got Success is walking from failure to failure with no loss of enthusiasm Just when the caterpillar thought the world was ending he turned into a butterfly Successful entrepreneurs are givers an
# ...

# %%
#text=formatted_article_text
# split into words by white space
words = text.split()

# split based on words only
import re
words = re.split(r'\W+', mot_text)
#print(words[:])

# remove all tokens that are not alphabetic
words = [word for word in words if word.isalpha()]
print(words[:])
# Out:
# ['If', 'you', 'want', 'to', 'achieve', 'greatness', 'stop', 'asking', 'for', 'permission', 'Things', 'work', 'out', 'best', 'for', 'those', 'who', 'make', 'the', 'best', 'of', 'how', 'things', 'work', 'out', 'To', 'live', 'a', 'creative', 'life', 'we', 'must', 'lose', 'our', 'fear', 'of', 'being', 'wrong', 'If', 'you', 'are', 'not', 'willing', 'to', 'risk', 'the', 'usual', 'you', 'will', 'have', 'to', 'settle', 'for', 'the', 'ordinary', 'Trust', 'because', 'you', 'are', 'willing', 'to', 'accept', 'the', 'risk', 'not', 'because', 'it', 's', 'safe', 'or', 'certain', 'Take', 'up', 'one', 'idea', 'Make', 'that', 'one', 'idea', 'your', 'life', 'think', 'of', 'it', 'dream', 'of', 'it', 'live', 'on', 'that', 'idea', 'Let', 'the', 'brain', 'muscles', 'nerves', 'every', 'part', 'of', 'your', 'body', 'be', 'full', 'of', 'that', 'idea', 'and', 'just', 'leave', 'every', 'other', 'idea', 'alone', 'This', 'is', 'the', 'way', 'to', 'success', 'All', 'our', 'dreams', 'can', 'come', 'true', 'if', 'we
# ...

# %%
filtered=words
for item in filtered:
    if len(item) <= 2:
        print ("length of %s is: %s" %(item, len(item)))
        filtered.remove(item)
    if item == "the":
        filtered.remove(item)
        print(item)
        print ("length of %s is: %s" %(item, len(item)))
    for i in filtered:
        if i == item:
            filtered.remove(item)
            print(item)
# Out:
# length of If is: 2
# If
# If
# If
# want
# achieve
# stop
# for
# for
# for
# for
# Things
# out
# out
# out
# those
# those
# make
# make
# best
# best
# things
# things
# things
# length of To is: 2
# length of a is: 1
# a
# a
# a
# a
# a
# life
# life
# must
# our
# our
# length of of is: 2
# of
# of
# of
# of
# of
# of
# of
# of
# of
# you
# you
# you
# you
# you
# you
# you
# you
# you
# you
# you
# you
# you
# willing
# willing
# risk
# risk
# usual
# have
# have
# have
# have
# settle
# ordinary
# because
# because
# length of to is: 2
# to
# to
# to
# to
# to
# to
# to
# to
# to
# to
# to
# length of s is: 1
# length of or is: 2
# Take
# one
# one
# one
# one
# Make
# idea
# idea
# idea
# idea
# idea
# length of it is: 2
# it
# it
# it
# length of on is: 2
# Let
# brain
# nerves
# part
# body
# full
# and
# and
# and
# and
# leave
# other
# This
# the
# length of the is: 3
# the
# the
# the
# the
# the
# the
# the
# the
# the
# the
# the
# true
# length of we is: 2
# we
# ...

# %%
filtered
# Out:
# ['greatness',
#  'asking',
#  'permission',
#  'work',
#  'who',
#  'how',
#  'work',
#  'live',
#  'creative',
#  'lose',
#  'fear',
#  'being',
#  'wrong',
#  'are',
#  'Trust',
#  'are',
#  'accept',
#  'safe',
#  'certain',
#  'up',
#  'think',
#  'dream',
#  'live',
#  'muscles',
#  'every',
#  'be',
#  'just',
#  'every',
#  'alone',
#  'way',
#  'success',
#  'All',
#  'dreams',
#  'if',
#  'courage',
#  'pursue',
#  'Good',
#  'who',
#  'but',
#  'who',
#  'get',
#  'what',
#  'did',
#  'get',
#  'what',
#  'Success',
#  'walking',
#  'from',
#  'failure',
#  'no',
#  'enthusiasm',
#  'when',
#  'thought',
#  'was',
#  'he',
#  'into',
#  'Successful',
#  'are',
#  'positive',
#  'Whenever',
#  'only',
#  'glories',
#  'private',
#  'reach',
#  'don',
#  'happen',
#  'Try',
#  'become',
#  'success',
#  'but',
#  'rather',
#  'become',
#  'Great',
#  'average',
#  'events',
#  'small',
#  'failed',
#  've',
#  'just',
#  'ways',
#  'won',
#  'work',
#  'don',
#  'neither',
# ...

# %%
for item in filtered:
    if len(item) <= 2:
        print ("length of %s is: %s" %(item, len(item)))
        filtered.remove(item)
# Out:
# length of up is: 2
# length of be is: 2
# length of if is: 2
# length of no is: 2
# length of he is: 2
# length of ve is: 2
# length of A is: 1
# length of at is: 2

# %%
final_list = [] 
for x in filtered:
    if x not in final_list: 
        final_list.append(x)

# %%
pos_words=final_list

# %%
pos_words
# Out:
# ['greatness',
#  'asking',
#  'permission',
#  'work',
#  'who',
#  'how',
#  'live',
#  'creative',
#  'lose',
#  'fear',
#  'being',
#  'wrong',
#  'are',
#  'Trust',
#  'accept',
#  'safe',
#  'certain',
#  'think',
#  'dream',
#  'muscles',
#  'every',
#  'just',
#  'alone',
#  'way',
#  'success',
#  'All',
#  'dreams',
#  'courage',
#  'pursue',
#  'Good',
#  'but',
#  'get',
#  'what',
#  'did',
#  'Success',
#  'walking',
#  'from',
#  'failure',
#  'enthusiasm',
#  'when',
#  'thought',
#  'was',
#  'into',
#  'Successful',
#  'positive',
#  'Whenever',
#  'only',
#  'glories',
#  'private',
#  'reach',
#  'don',
#  'happen',
#  'Try',
#  'become',
#  'rather',
#  'Great',
#  'average',
#  'events',
#  'small',
#  'failed',
#  'ways',
#  'won',
#  'neither',
#  'Stop',
#  'away',
#  'talents',
#  'start',
#  'charging',
#  'man',
#  'lay',
#  'firm',
#  'bricks',
#  'No',
#  'inferior',
#  'consent']

# %% [markdown]
# # demotivatinal quotes

# %%
# load text
filename = 'demotivation quotes.txt'
file = open(filename, 'rt')
demot = file.read()
file.close()
demot
# Out:
# "1. There's only one you,and that's a good thing.\n2. It could always get worse.\n3. Given a choice, you will always choose wrong.\n4. You are a child of the universe. Problem is, the universe is a deadbeat dad.\n5. It is what it is. And its not good.\n6. Love conquers all, except for herpes.\n7. If you changed everything about you, I'd love you just the way you are.\n8. Some are born great, some achieve greatness and some wind up like you.\n9. Please take your feelings and tuck them back inside your heart.\n10. Everyone's good at something, and you're the best at not being good at anything.\n11. You arent being paid to believe in power of dreams..\n12. Things can't be bad, they can be worse.\n13. Accept that you're just a product, not a gift.\n14. Your mother's biggest regret is you.\n15. The journey of thousand miles sometimes end very badly.\n16. Happy people do not wake up for breakfast.\n17. The glass is neither half-empty nor half-full; it's full of shit.\n18. Life is only logi
# ...

# %%
from nltk.tokenize import sent_tokenize
demot_sent=sent_tokenize(demot)
demot_sent
# Out:
# ['1.',
#  "There's only one you,and that's a good thing.",
#  '2.',
#  'It could always get worse.',
#  '3.',
#  'Given a choice, you will always choose wrong.',
#  '4.',
#  'You are a child of the universe.',
#  'Problem is, the universe is a deadbeat dad.',
#  '5.',
#  'It is what it is.',
#  'And its not good.',
#  '6.',
#  'Love conquers all, except for herpes.',
#  '7.',
#  "If you changed everything about you, I'd love you just the way you are.",
#  '8.',
#  'Some are born great, some achieve greatness and some wind up like you.',
#  '9.',
#  'Please take your feelings and tuck them back inside your heart.',
#  '10.',
#  "Everyone's good at something, and you're the best at not being good at anything.",
#  '11.',
#  'You arent being paid to believe in power of dreams..\n12.',
#  "Things can't be bad, they can be worse.",
#  '13.',
#  "Accept that you're just a product, not a gift.",
#  '14.',
#  "Your mother's biggest regret is you.",
#  '15.',
# ...

# %%
import nltk
import nltk.tokenize as nt
import re


# Removing Square Brackets and Extra Spaces
demot_text = re.sub(r'\[[0-9]*\]', ' ', demot)  
demot_text = re.sub(r'\s+', ' ', demot_text) 

# Removing special characters and digits
demot_text = re.sub('[^a-zA-Z]', ' ', demot_text )  
demot_text = re.sub(r'\s+', ' ', demot_text)



demot_text
# Out:
# ' There s only one you and that s a good thing It could always get worse Given a choice you will always choose wrong You are a child of the universe Problem is the universe is a deadbeat dad It is what it is And its not good Love conquers all except for herpes If you changed everything about you I d love you just the way you are Some are born great some achieve greatness and some wind up like you Please take your feelings and tuck them back inside your heart Everyone s good at something and you re the best at not being good at anything You arent being paid to believe in power of dreams Things can t be bad they can be worse Accept that you re just a product not a gift Your mother s biggest regret is you The journey of thousand miles sometimes end very badly Happy people do not wake up for breakfast The glass is neither half empty nor half full it s full of shit Life is only logical and to think it s a gift is depressing Just wanted to tell you I m not thinking about you Try try until 
# ...

# %%
# split based on words only
import re
words = re.split(r'\W+', demot_text)
#print(words[:])

# remove all tokens that are not alphabetic
dewords = [word for word in words if word.isalpha()]
print(dewords[:])
# Out:
# ['There', 's', 'only', 'one', 'you', 'and', 'that', 's', 'a', 'good', 'thing', 'It', 'could', 'always', 'get', 'worse', 'Given', 'a', 'choice', 'you', 'will', 'always', 'choose', 'wrong', 'You', 'are', 'a', 'child', 'of', 'the', 'universe', 'Problem', 'is', 'the', 'universe', 'is', 'a', 'deadbeat', 'dad', 'It', 'is', 'what', 'it', 'is', 'And', 'its', 'not', 'good', 'Love', 'conquers', 'all', 'except', 'for', 'herpes', 'If', 'you', 'changed', 'everything', 'about', 'you', 'I', 'd', 'love', 'you', 'just', 'the', 'way', 'you', 'are', 'Some', 'are', 'born', 'great', 'some', 'achieve', 'greatness', 'and', 'some', 'wind', 'up', 'like', 'you', 'Please', 'take', 'your', 'feelings', 'and', 'tuck', 'them', 'back', 'inside', 'your', 'heart', 'Everyone', 's', 'good', 'at', 'something', 'and', 'you', 're', 'the', 'best', 'at', 'not', 'being', 'good', 'at', 'anything', 'You', 'arent', 'being', 'paid', 'to', 'believe', 'in', 'power', 'of', 'dreams', 'Things', 'can', 't', 'be', 'bad', 'they', 'can',
# ...

# %%
filtered=dewords
for item in filtered:
    if len(item) <= 2:
        print ("length of %s is: %s" %(item, len(item)))
        filtered.remove(item)
    if item == "the":
        filtered.remove(item)
        print(item)
        print ("length of %s is: %s" %(item, len(item)))
    for i in filtered:
        if i == item:
            filtered.remove(item)
            print(item)
# Out:
# There
# only
# only
# you
# you
# you
# you
# you
# you
# you
# you
# you
# you
# you
# you
# you
# that
# that
# length of a is: 1
# a
# a
# a
# a
# a
# a
# thing
# could
# get
# Given
# will
# choose
# You
# You
# child
# the
# length of the is: 3
# the
# the
# the
# Problem
# universe
# universe
# dad
# length of is is: 2
# is
# is
# is
# is
# is
# is
# is
# its
# good
# good
# good
# good
# all
# for
# for
# length of If is: 2
# everything
# length of I is: 1
# I
# love
# way
# Some
# born
# some
# some
# greatness
# wind
# like
# take
# feelings
# tuck
# back
# your
# your
# length of s is: 1
# s
# s
# s
# s
# s
# length of re is: 2
# re
# length of at is: 2
# at
# at
# anything
# being
# being
# believe
# power
# dreams
# can
# can
# length of be is: 2
# be
# they
# Accept
# product
# gift
# gift
# mother
# regret
# journey
# thousand
# sometimes
# very
# Happy
# length of do is: 2
# wake
# breakfast
# glass
# half
# half
# nor
# length of it is: 2
# it
# it
# shit
# logical
# ...

# %%
for item in filtered:
    if len(item) <= 2:
        print ("length of %s is: %s" %(item, len(item)))
        filtered.remove(item)

# %%
final_list = [] 
for x in filtered:
    if x not in final_list: 
        final_list.append(x)

# %%
neg_words=final_list

# %% [markdown]
# # processing

# %%
pos_words
# Out:
# ['greatness',
#  'asking',
#  'permission',
#  'work',
#  'who',
#  'how',
#  'live',
#  'creative',
#  'lose',
#  'fear',
#  'being',
#  'wrong',
#  'are',
#  'Trust',
#  'accept',
#  'safe',
#  'certain',
#  'think',
#  'dream',
#  'muscles',
#  'every',
#  'just',
#  'alone',
#  'way',
#  'success',
#  'All',
#  'dreams',
#  'courage',
#  'pursue',
#  'Good',
#  'but',
#  'get',
#  'what',
#  'did',
#  'Success',
#  'walking',
#  'from',
#  'failure',
#  'enthusiasm',
#  'when',
#  'thought',
#  'was',
#  'into',
#  'Successful',
#  'positive',
#  'Whenever',
#  'only',
#  'glories',
#  'private',
#  'reach',
#  'don',
#  'happen',
#  'Try',
#  'become',
#  'rather',
#  'Great',
#  'average',
#  'events',
#  'small',
#  'failed',
#  'ways',
#  'won',
#  'neither',
#  'Stop',
#  'away',
#  'talents',
#  'start',
#  'charging',
#  'man',
#  'lay',
#  'firm',
#  'bricks',
#  'No',
#  'inferior',
#  'consent']

# %%
for x in neg_words:
    if x in pos_words: 
        neg_words.remove(x)
neg_words
# Out:
# ['one',
#  'and',
#  'always',
#  'worse',
#  'choice',
#  'deadbeat',
#  'And',
#  'Love',
#  'conquers',
#  'except',
#  'herpes',
#  'changed',
#  'about',
#  'great',
#  'achieve',
#  'Please',
#  'them',
#  'inside',
#  'heart',
#  'Everyone',
#  'something',
#  'best',
#  'arent',
#  'paid',
#  'Things',
#  'bad',
#  'Your',
#  'biggest',
#  'The',
#  'miles',
#  'end',
#  'badly',
#  'people',
#  'empty',
#  'full',
#  'of',
#  'Life',
#  'depressing',
#  'wanted',
#  'thinking',
#  'try',
#  'until',
#  'succeed']
